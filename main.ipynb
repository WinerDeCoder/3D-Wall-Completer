# %%
#import GeometricTools
from noise_removal import *
import seaborn
import numpy as np

from glob import glob

# %%
paths = glob('wall_nphuc/*_wall.npy')
paths = sorted(paths)

# %%
def statistic_outlier_removal(pcd, nb_neighbors=10, std_ratio=1.0):
    _, ind = pcd.remove_statistical_outlier(nb_neighbors=nb_neighbors,
                                                    std_ratio=std_ratio)
    
    display_inlier_outlier(pcd, ind)
    inlier_cloud = pcd.select_by_index(ind)
    o3d.visualization.draw_geometries([inlier_cloud], "Statistical oulier removal")
    return inlier_cloud

# %%
def radius_outlier_removal(pcd, nb_points=30, radius=0.08):
    _, ind = pcd.remove_radius_outlier(nb_points=nb_points, radius=radius)
    display_inlier_outlier(pcd, ind)
    inlier_cloud = pcd.select_by_index(ind)
    o3d.visualization.draw_geometries([inlier_cloud], "Radius oulier removal")
    return inlier_cloud

# %%
for path in paths:
    print(path)
    numpy_array     = np.load(path)
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(numpy_array)
    print("before", pcd.points)
    pcd = radius_outlier_removal(pcd)
    print("after", pcd.points)
    print("-----------")
    #pcd             = o3d.io.read_point_cloud(path)
    point_numpy = np.asarray(pcd.points)
    print(point_numpy.shape)
    np.save(f'np_points/{path[11:]}', point_numpy)
# Out:
# wall_nphuc/0_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 15479 elements.
# Use numpy.asarray() to access data.
# -----------
# (15479, 3)
# wall_nphuc/10_wall.npy
# before std::vector<Eigen::Vector3d> with 65536 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 50043 elements.
# Use numpy.asarray() to access data.
# -----------
# (50043, 3)
# wall_nphuc/11_wall.npy
# before std::vector<Eigen::Vector3d> with 49152 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 40726 elements.
# Use numpy.asarray() to access data.
# -----------
# (40726, 3)
# wall_nphuc/12_wall.npy
# before std::vector<Eigen::Vector3d> with 24576 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 24538 elements.
# Use numpy.asarray() to access data.
# -----------
# (24538, 3)
# wall_nphuc/13_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 24103 elements.
# Use numpy.asarray() to access data.
# -----------
# (24103, 3)
# wall_nphuc/14_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 8685 elements.
# Use numpy.asarray() to access data.
# -----------
# (8685, 3)
# wall_nphuc/15_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 11766 elements.
# Use numpy.asarray() to access data.
# -----------
# (11766, 3)
# wall_nphuc/16_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 16423 elements.
# Use numpy.asarray() to access data.
# -----------
# (16423, 3)
# wall_nphuc/17_wall.npy
# before std::vector<Eigen::Vector3d> with 65536 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 33758 elements.
# Use numpy.asarray() to access data.
# -----------
# (33758, 3)
# wall_nphuc/18_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 22673 elements.
# Use numpy.asarray() to access data.
# -----------
# (22673, 3)
# wall_nphuc/19_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 16056 elements.
# Use numpy.asarray() to access data.
# -----------
# (16056, 3)
# wall_nphuc/1_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 23983 elements.
# Use numpy.asarray() to access data.
# -----------
# (23983, 3)
# wall_nphuc/20_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 21510 elements.
# Use numpy.asarray() to access data.
# -----------
# (21510, 3)
# wall_nphuc/21_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 18666 elements.
# Use numpy.asarray() to access data.
# -----------
# (18666, 3)
# wall_nphuc/2_wall.npy
# before std::vector<Eigen::Vector3d> with 212992 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 148975 elements.
# Use numpy.asarray() to access data.
# -----------
# (148975, 3)
# wall_nphuc/3_wall.npy
# before std::vector<Eigen::Vector3d> with 163840 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 145550 elements.
# Use numpy.asarray() to access data.
# -----------
# (145550, 3)
# wall_nphuc/4_wall.npy
# before std::vector<Eigen::Vector3d> with 24576 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 136 elements.
# Use numpy.asarray() to access data.
# -----------
# (136, 3)
# wall_nphuc/5_wall.npy
# before std::vector<Eigen::Vector3d> with 24576 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 8302 elements.
# Use numpy.asarray() to access data.
# -----------
# (8302, 3)
# wall_nphuc/6_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 31578 elements.
# Use numpy.asarray() to access data.
# -----------
# (31578, 3)
# wall_nphuc/7_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 14651 elements.
# Use numpy.asarray() to access data.
# -----------
# (14651, 3)
# wall_nphuc/8_wall.npy
# before std::vector<Eigen::Vector3d> with 32768 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 15334 elements.
# Use numpy.asarray() to access data.
# -----------
# (15334, 3)
# wall_nphuc/9_wall.npy
# before std::vector<Eigen::Vector3d> with 139264 elements.
# Use numpy.asarray() to access data.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
# after std::vector<Eigen::Vector3d> with 108555 elements.
# Use numpy.asarray() to access data.
# -----------
# (108555, 3)
